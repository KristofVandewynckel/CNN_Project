# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report

# %%
data = pd.read_csv('../../images/hmnist_28_28_RGB.csv')
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 0        138        183        147        166        185        154
# 1         55         25         14         28         25         14
# 2        143        159        124        142        136        104
# 3         36         25         12         17         25         12
# 4        185        172        135        149        109         78
#
#    pixel2351  label
# 0        177      2
# 1         27      2
# 2        117      2
# 3         15      2
# 4         92      2
#
# [5 rows x 2353 columns]

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
y = data['label'].copy()
X = data.drop('label', axis=1).copy()

# %%
y.value_counts()
# Out:
# 4    6705
# 6    1113
# 2    1099
# 1     514
# 0     327
# 5     142
# 3     115
# Name: label, dtype: int64

# %%
label_mapping = {
    0: 'nv',
    1: 'mel',
    2: 'bkl',
    3: 'bcc',
    4: 'akiec',
    5: 'vasc',
    6: 'df'
}

# %%
X = X / 255

X
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0       0.662745   0.670588   0.666667   0.694118   0.709804   0.713725
# 1       0.074510   0.223529   0.411765   0.549020   0.584314   0.580392
# 2       0.607843   0.639216   0.631373   0.654902   0.654902   0.674510
# 3       0.098039   0.278431   0.454902   0.545098   0.533333   0.600000
# 4       0.505882   0.635294   0.709804   0.768627   0.803922   0.815686
# ...          ...        ...        ...        ...        ...        ...
# 10010   0.674510   0.670588   0.678431   0.686275   0.643137   0.733333
# 10011   0.007843   0.133333   0.423529   0.454902   0.447059   0.466667
# 10012   0.478431   0.603922   0.635294   0.666667   0.701961   0.772549
# 10013   0.537255   0.560784   0.552941   0.545098   0.576471   0.596078
# 10014   0.584314   0.615686   0.615686   0.596078   0.592157   0.596078
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel0774  pixel0775  \
# 0       0.709804   0.725490   0.760784   0.752941  ...   0.690196   0.721569
# 1       0.564706   0.607843   0.666667   0.666667  ...   0.709804   0.674510
# 2       0.607843   0.596078   0.647059   0.686275  ...   0.635294   0.639216
# 3       0.580392   0.631373   0.674510   0.635294  ...   0.556863   0.490196
# 4       0.803922   0.835294   0.882353   0.878431  ...   0.827451   0.823529
# ...          ...        ...        ...        ...  ...        ...        ...
# 10010   0.811765   0.823529   0.815686   0.807843  ...   0.823529   0.823529
# 10011   0.513725   0.545098   0.545098   0.568627  ...   0.721569   0.678431
# 10012   0.784314   0.764706   0.792157   0.780392  ...   0.874510   0.866667
# 10013   0.607843   0.596078   0.607843   0.623529  ...   0.698039   0.674510
# 10014   0.603922   0.639216   0.584314   0.568627  ...   0.650980   0.623529
#
#        pixel0776  pixel0777  pixel0778  pixel0779  pixel0780  pixel0781  \
# 0       0.729412   0.725490   0.705882   0.615686   0.549020   0.549020
# 1       0.686275   0.627451   0.564706   0.447059   0.349020   0.184314
# 2       0.698039   0.615686   0.650980   0.654902   0.580392   0.552941
# 3       0.529412   0.541176   0.537255   0.435294   0.278431   0.125490
# 4       0.772549   0.674510   0.745098   0.764706   0.756863   0.709804
# ...          ...        ...        ...        ...        ...        ...
# 10010   0.850980   0.866667   0.819608   0.725490   0.733333   0.752941
# 10011   0.662745   0.658824   0.658824   0.560784   0.541176   0.325490
# 10012   0.843137   0.803922   0.733333   0.819608   0.776471   0.733333
# 10013   0.670588   0.686275   0.717647   0.694118   0.666667   0.662745
# 10014   0.603922   0.568627   0.415686   0.262745   0.243137   0.403922
#
#        pixel0782  pixel0783
# 0       0.623529   0.647059
# 1       0.070588   0.070588
# 2       0.533333   0.450980
# 3       0.062745   0.062745
# 4       0.576471   0.345098
# ...          ...        ...
# 10010   0.752941   0.752941
# 10011   0.090196   0.011765
# 10012   0.643137   0.611765
# 10013   0.650980   0.666667
# 10014   0.572549   0.580392
#
# [10015 rows x 784 columns]

# %%
X = np.array(X)
print(X.shape)

X = X.reshape(-1, 28, 28, 1)
print(X.shape)
# Out:
# (10015, 784)
# (10015, 28, 28, 1)

# %%
sample_data = pd.Series(list(zip(X, y))).sample(9)

sample_X = np.stack(np.array(sample_data.apply(lambda x: x[0])))
sample_y = np.array(sample_data.apply(lambda x: x[1]))

# %%
plt.figure(figsize=(12, 12))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(np.squeeze(sample_X[i]))
    img_label = label_mapping[sample_y[i]]
    plt.title(img_label)
    plt.axis("off")

plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=123)

# %%
inputs = tf.keras.Input(shape=(28, 28, 1), name='input')

conv1 = tf.keras.layers.Conv2D(filters=16, kernel_size=3, name='conv1')(inputs)
maxpool1 = tf.keras.layers.MaxPooling2D(name='maxpool1')(conv1)

conv2 = tf.keras.layers.Conv2D(filters=32, kernel_size=3, name='conv2')(maxpool1)
maxpool2 = tf.keras.layers.MaxPooling2D(name='maxpool2')(conv2)

conv3 = tf.keras.layers.Conv2D(filters=64, kernel_size=3, name='conv3')(maxpool2)
maxpool3 = tf.keras.layers.MaxPooling2D(name='maxpool3')(conv3)

avgpool = tf.keras.layers.GlobalAveragePooling2D(name='avgpool')(maxpool3)

outputs = tf.keras.layers.Dense(7, activation='softmax', name='output')(avgpool)


model = tf.keras.Model(inputs=inputs, outputs=outputs)

print(model.summary())
tf.keras.utils.plot_model(model)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 28, 28, 1)]       0
#
#  conv1 (Conv2D)              (None, 26, 26, 16)        160
#
#  maxpool1 (MaxPooling2D)     (None, 13, 13, 16)        0
#
#  conv2 (Conv2D)              (None, 11, 11, 32)        4640
#
#  maxpool2 (MaxPooling2D)     (None, 5, 5, 32)          0
#
#  conv3 (Conv2D)              (None, 3, 3, 64)          18496
#
#  maxpool3 (MaxPooling2D)     (None, 1, 1, 64)          0
#
#  avgpool (GlobalAveragePooli  (None, 64)               0
#  ng2D)
#
#  output (Dense)              (None, 7)                 455
#
# =================================================================
# Total params: 23,751
# Trainable params: 23,751
# Non-trainable params: 0
# _________________________________________________________________
# None
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


batch_size = 32
epochs = 50

history = model.fit(
    X_train,
    y_train,
    validation_split=0.2,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(
            monitor='accuracy',
            patience=3,
            restore_best_weights=True
        )
    ]
)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 2s 9ms/step - loss: 1.1229 - accuracy: 0.6737 - val_loss: 1.0867 - val_accuracy: 0.6583
# Epoch 2/50
# 176/176 [==============================] - 2s 10ms/step - loss: 1.0287 - accuracy: 0.6749 - val_loss: 1.0413 - val_accuracy: 0.6548
# Epoch 3/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.9973 - accuracy: 0.6758 - val_loss: 1.0200 - val_accuracy: 0.6576
# Epoch 4/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.9454 - accuracy: 0.6822 - val_loss: 0.9773 - val_accuracy: 0.6612
# Epoch 5/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.9216 - accuracy: 0.6851 - val_loss: 0.9611 - val_accuracy: 0.6619
# Epoch 6/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.9047 - accuracy: 0.6851 - val_loss: 0.9744 - val_accuracy: 0.6669
# Epoch 7/50
# 176/176 [==============================] - 2s 14ms/step - loss: 0.8917 - accuracy: 0.6897 - val_loss: 0.9507 - val_accuracy: 0.6712
# Epoch 8/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.8790 - accuracy: 0.6969 - val_loss: 0.9648 - val_accuracy: 0.6698
# Epoch 9/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.8734 - accuracy: 0.7001 - val_loss: 0.9407 - val_accuracy: 0.6840
# Epoch 10/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.8613 - accuracy: 0.7001 - val_loss: 0.9789 - val_accuracy: 0.6712
# Epoch 11/50
# 176/176 [==============================] - 2s 14ms/step - loss: 0.8585 - accuracy: 0.7020 - val_loss: 0.9274 - val_accuracy: 0.6826
# Epoch 12/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.8495 - accuracy: 0.7058 - val_loss: 0.9061 - val_accuracy: 0.6840
# Epoch 13/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.8392 - accuracy: 0.7109 - val_loss: 0.9421 - val_accuracy: 0.6769
# Epoch 14/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.8351 - accuracy: 0.7118 - val_loss: 0.9421 - val_accuracy: 0.6797
# Epoch 15/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.8359 - accuracy: 0.7111 - val_loss: 0.9080 - val_accuracy: 0.6805
# Epoch 16/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.8252 - accuracy: 0.7129 - val_loss: 0.9270 - val_accuracy: 0.6783
# Epoch 17/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.8122 - accuracy: 0.7168 - val_loss: 0.9016 - val_accuracy: 0.6833
# Epoch 18/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.8003 - accuracy: 0.7240 - val_loss: 0.9128 - val_accuracy: 0.6904
# Epoch 19/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.7997 - accuracy: 0.7213 - val_loss: 0.9278 - val_accuracy: 0.6883
# Epoch 20/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.7882 - accuracy: 0.7256 - val_loss: 0.9178 - val_accuracy: 0.6976
# Epoch 21/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.7850 - accuracy: 0.7261 - val_loss: 0.9177 - val_accuracy: 0.6819
# Epoch 22/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.7700 - accuracy: 0.7300 - val_loss: 0.9244 - val_accuracy: 0.6954
# Epoch 23/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.7613 - accuracy: 0.7343 - val_loss: 0.9595 - val_accuracy: 0.6719
# Epoch 24/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.7484 - accuracy: 0.7388 - val_loss: 0.9286 - val_accuracy: 0.6826
# Epoch 25/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.7377 - accuracy: 0.7438 - val_loss: 0.9498 - val_accuracy: 0.6897
# Epoch 26/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.7223 - accuracy: 0.7514 - val_loss: 0.9659 - val_accuracy: 0.6876
# Epoch 27/50
# 176/176 [==============================] - 2s 14ms/step - loss: 0.7136 - accuracy: 0.7546 - val_loss: 0.9383 - val_accuracy: 0.6812
# Epoch 28/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.7095 - accuracy: 0.7561 - val_loss: 0.9377 - val_accuracy: 0.6883
# Epoch 29/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.6975 - accuracy: 0.7543 - val_loss: 0.9624 - val_accuracy: 0.6783
# Epoch 30/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.6834 - accuracy: 0.7648 - val_loss: 0.9601 - val_accuracy: 0.6904
# Epoch 31/50
# 176/176 [==============================] - 3s 15ms/step - loss: 0.6677 - accuracy: 0.7664 - val_loss: 0.9716 - val_accuracy: 0.6869
# Epoch 32/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.6621 - accuracy: 0.7677 - val_loss: 0.9789 - val_accuracy: 0.6755
# Epoch 33/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.6535 - accuracy: 0.7735 - val_loss: 0.9497 - val_accuracy: 0.6854
# Epoch 34/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.6297 - accuracy: 0.7814 - val_loss: 0.9775 - val_accuracy: 0.6626
# Epoch 35/50
# 176/176 [==============================] - 2s 14ms/step - loss: 0.6182 - accuracy: 0.7839 - val_loss: 1.0094 - val_accuracy: 0.6690
# Epoch 36/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.5999 - accuracy: 0.7919 - val_loss: 1.0058 - val_accuracy: 0.6862
# Epoch 37/50
# 176/176 [==============================] - 2s 14ms/step - loss: 0.5947 - accuracy: 0.7932 - val_loss: 0.9988 - val_accuracy: 0.6755
# Epoch 38/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.5760 - accuracy: 0.8065 - val_loss: 1.0280 - val_accuracy: 0.6569
# Epoch 39/50
# 176/176 [==============================] - 3s 14ms/step - loss: 0.5752 - accuracy: 0.8051 - val_loss: 1.0545 - val_accuracy: 0.6797
# Epoch 40/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.5581 - accuracy: 0.8047 - val_loss: 1.0498 - val_accuracy: 0.6790
# Epoch 41/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.5383 - accuracy: 0.8162 - val_loss: 1.0313 - val_accuracy: 0.6740
# Epoch 42/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.5308 - accuracy: 0.8228 - val_loss: 1.0381 - val_accuracy: 0.6676
# Epoch 43/50
# 176/176 [==============================] - 2s 10ms/step - loss: 0.5184 - accuracy: 0.8252 - val_loss: 1.0708 - val_accuracy: 0.6726
# Epoch 44/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.5008 - accuracy: 0.8290 - val_loss: 1.0807 - val_accuracy: 0.6705
# Epoch 45/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.5046 - accuracy: 0.8311 - val_loss: 1.1271 - val_accuracy: 0.6662
# Epoch 46/50
# 176/176 [==============================] - 2s 13ms/step - loss: 0.4852 - accuracy: 0.8326 - val_loss: 1.0872 - val_accuracy: 0.6726
# Epoch 47/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4626 - accuracy: 0.8445 - val_loss: 1.1055 - val_accuracy: 0.6655
# Epoch 48/50
# 176/176 [==============================] - 2s 11ms/step - loss: 0.4525 - accuracy: 0.8463 - val_loss: 1.1563 - val_accuracy: 0.6662
# Epoch 49/50
# 176/176 [==============================] - 2s 10ms/step - loss: 0.4350 - accuracy: 0.8522 - val_loss: 1.1943 - val_accuracy: 0.6362
# Epoch 50/50
# 176/176 [==============================] - 2s 12ms/step - loss: 0.4340 - accuracy: 0.8527 - val_loss: 1.1963 - val_accuracy: 0.6769

# %%
model_acc = model.evaluate(X_test, y_test, verbose=0)[1]

print("Test Accuracy: {:.3f}%".format(model_acc * 100))
# Out:
# Test Accuracy: 68.918%

# %%
y_true = np.array(y_test)

y_pred = model.predict(X_test)
y_pred = np.array(list(map(lambda x: np.argmax(x), y_pred)))

# %%
cm = confusion_matrix(y_true, y_pred)
clr = classification_report(y_true, y_pred, target_names=label_mapping.values())

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='g', vmin=0, cbar=False, cmap='Blues')

plt.xticks(np.arange(7) + 0.5, label_mapping.values())
plt.xlabel("Predicted")

plt.yticks(np.arange(7) + 0.5, label_mapping.values())
plt.ylabel("Actual")

plt.title("Confusion Matrix")

plt.show()

# %%
print(clr)
# Out:
#               precision    recall  f1-score   support
#
#           nv       0.25      0.23      0.24        94
#          mel       0.37      0.23      0.28       154
#          bkl       0.40      0.31      0.35       328
#          bcc       1.00      0.08      0.15        37
#        akiec       0.78      0.92      0.84      1990
#         vasc       0.00      0.00      0.00        49
#           df       0.40      0.22      0.29       353
#
#     accuracy                           0.69      3005
#    macro avg       0.46      0.28      0.31      3005
# weighted avg       0.64      0.69      0.65      3005
